# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Title of NoteBook is Nadeem_notbook

# %% [markdown]
# This is an introudction Markdown cell

# %% [markdown]
# # dataScience Languages
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. JAVA
# 6. C++
# 7. Julia

# %% [markdown]
# # Data Science Libraries
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-Learn
# 6. Keras
# 7. TensorFlow
# 8. Pytorch
# 9. ApacheSpark
# 10. ggplot

# %% [markdown]
# # data science tools
# |SrNo|Languae|
# |----|----|
# |1|Tensor Flow|
# |2|Rapid Miner|
# |3|Pandas|
# |4|NumPy|
# |5|Pytorch|
# |6|Keras|
# |7|RStudio|
# |8|Julia|

# %% [markdown]
# # Arithmtic Expression Example
# we can provide direct expression to code cell in jupyter notbook <br>
# When we do this, it will give the result of expression<br>
# For example , consider the following expression <br>
# =***3+6*** <br>
# =*9* <br>
# In the same way we can use any expression

# %%
first_num = 5
sec_num = 6
sum = first_num + sec_num
mul = first_num * sec_num
print("The sum is ", sum ," and multiply result is ",mul)
# Out:
# The sum is  11  and multiply result is  30

# %%
minutes = 546
hours = minutes / 60
print("The hours are ", hours)
# Out:
# The hours are  9.1

# %% [markdown]
# # this cell lists the objective of this course series
# These are the objectives of this course
# * Create a Jupyter Notebook with markdown and code cells
# * List examples of languages, libraries and tools used in Data Science
# * Share your Jupyter Notebook publicly on GitHub
# * Evaluate notebooks submitted by your peers using the provided rubric
# * Demonstrate proficiency in Data Science toolkit knowledge

# %% [markdown]
# # this cell lists the authors
# * Aije Egwaikhide
# * Svetlana Levitan
# * Romeo Kienzler

# %% [markdown]
# # here is the URL of this NoteBook publicly avaiable of GitHub

# %% [markdown]
# # Screenshot of First page of NoteBook
# ![juptrer.png](attachment:357010f4-b134-4b0c-a7ca-d8fca2d4f033.png)
